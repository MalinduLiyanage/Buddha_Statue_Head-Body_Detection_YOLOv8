# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 20.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO
import os

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 112MB/s]

# %%
ROOT_DIR = '/content/drive/MyDrive/Colab Notebooks/Object Detector/Model_Training'

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Save the files to Google Drive
#Restart the session if the code gives an error
# %cp -av "/content/runs" "/content/drive/MyDrive/Colab Notebooks/Object Detector"
# Out:
# '/content/runs' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs'
# '/content/runs/detect' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs/detect'
# '/content/runs/detect/train' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs/detect/train'
# '/content/runs/detect/train/weights' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs/detect/train/weights'
# '/content/runs/detect/train/args.yaml' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs/detect/train/args.yaml'
# '/content/runs/detect/train2' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs/detect/train2'
# '/content/runs/detect/train2/weights' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs/detect/train2/weights'
# '/content/runs/detect/train2/args.yaml' -> '/content/drive/MyDrive/Colab Notebooks/Object Detector/runs/detect/train2/args.yaml'
# ...
